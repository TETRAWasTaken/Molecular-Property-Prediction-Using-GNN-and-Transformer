# %%
import pandas as pd 
import numpy as np

# %%
with np.load("/Users/anshumaansoni/PycharmProjects/Molecular-Property-Prediction-Using-GNN-and-Transformer/Evaluation/Hybrid/predictions.npz", allow_pickle=True) as data:
    print(data.files)
    pred = pd.DataFrame(data["y_pred"])
    true = pd.DataFrame(data["y_true"])
# Out:
# ['y_pred', 'y_true', 'smiles']

# %%
pred
# Out:
#              0          1         2         3         4            5   \
# 0      2.449490  80.322533 -0.241432 -0.007212  0.233412  1412.824585
# 1      3.127088  68.164421 -0.274489 -0.045124  0.228705  1176.512695
# 2      3.862666  70.648560 -0.262540 -0.000611  0.261275  1174.517944
# 3      1.424567  83.269661 -0.258298  0.060902  0.318299  1311.687256
# 4      0.203215  95.953354 -0.271368  0.095408  0.365433  1501.026733
# ...         ...        ...       ...       ...       ...          ...
# 11851  1.097664  85.849503 -0.232098  0.036242  0.267464  1333.737061
# 11852  0.774460  79.680389 -0.252807  0.065989  0.317634  1178.076416
# 11853  0.197111  66.908745 -0.221869  0.092777  0.314041   756.726074
# 11854  1.207242  84.544846 -0.240384  0.032847  0.272385  1368.450562
# 11855  0.604694  66.766708 -0.241395  0.050983  0.291698   702.734253
#
#              6             7             8             9             10  \
# ...

# %%
true
# Out:
#            0          1       2       3       4            5         6   \
# 0      3.9459  79.170006 -0.2321 -0.0849  0.1472  1220.620361  0.133291
# 1      1.9347  62.470001 -0.3085 -0.0936  0.2149  1112.378174  0.063086
# 2      5.7462  63.520004 -0.2788 -0.0352  0.2437   976.160400  0.090679
# 3      1.6268  74.540001 -0.2589  0.0864  0.3453  1065.253418  0.176234
# 4      0.1000  96.160004 -0.2608  0.0799  0.3407  1591.211548  0.250820
# ...       ...        ...     ...     ...     ...          ...       ...
# 11851  1.2736  87.920006 -0.2220  0.0212  0.2432  1246.910156  0.194809
# 11852  1.4519  79.180000 -0.2362  0.0804  0.3166   878.373901  0.188938
# 11853  1.0862  64.880005 -0.2101  0.0886  0.2987   644.905090  0.137621
# 11854  1.6762  83.900002 -0.2340  0.0160  0.2499  1219.244507  0.184127
# 11855  0.2213  67.810005 -0.2297  0.0237  0.2535   610.893127  0.151987
#
#                  7             8             9             10         11
# ...

# %%
diff = pred.iloc[:, 9] - true.iloc[:, 9]

# %%
diff
# Out:
# 0         -20.063477
# 1         159.322266
# 2         -98.415039
# 3        1056.386719
# 4         159.899414
#             ...
# 11851     318.368164
# 11852     748.747070
# 11853     606.017090
# 11854     135.629883
# 11855     535.456055
# Name: 9, Length: 11856, dtype: float64
